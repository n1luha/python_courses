# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
rng = np.random.default_rng(1)
data = rng.normal(size=1000)

plt.hist(data, bins=30, density=True, alpha=0.5, histtype='step', edgecolor='red')
# Out:
# (array([0.00410934, 0.00410934, 0.        , 0.02054671, 0.01232802,
#         0.05753078, 0.03287473, 0.09862419, 0.15615497, 0.20135773,
#         0.25066982, 0.3082006 , 0.34518468, 0.38216875, 0.44380887,
#         0.41504348, 0.2876539 , 0.31641929, 0.32052863, 0.14382695,
#         0.09451485, 0.07807749, 0.0698588 , 0.03698407, 0.00410934,
#         0.01232802, 0.00410934, 0.00410934, 0.        , 0.00410934]),
#  array([-3.54880497, -3.30545697, -3.06210898, -2.81876098, -2.57541298,
#         -2.33206498, -2.08871698, -1.84536899, -1.60202099, -1.35867299,
#         -1.11532499, -0.87197699, -0.628629  , -0.385281  , -0.141933  ,
#          0.101415  ,  0.344763  ,  0.58811099,  0.83145899,  1.07480699,
#          1.31815499,  1.56150299,  1.80485098,  2.04819898,  2.29154698,
#          2.53489498,  2.77824298,  3.02159097,  3.26493897,  3.50828697,
#          3.75163497]),
#  [<matplotlib.patches.Polygon at 0x22c6234bb80>])

# %%
rng = np.random.default_rng(1)
x1 = rng.normal(0, 0.8, 1000)
x2 = rng.normal(-2, 1, 1000)
x3 = rng.normal(3, 2, 1000)

args = dict(alpha=0.3, bins=40)

plt.hist(x1, **args)
plt.hist(x2, **args)
plt.hist(x3, **args)
# Out:
# (array([ 1.,  0.,  3.,  3.,  1.,  5.,  2., 10., 13., 15., 21., 24., 25.,
#         36., 36., 57., 54., 56., 49., 74., 58., 71., 63., 56., 55., 38.,
#         43., 35., 27., 17., 19., 10.,  9.,  4.,  5.,  0.,  2.,  1.,  0.,
#          2.]),
#  array([-3.34433518, -3.02717447, -2.71001376, -2.39285306, -2.07569235,
#         -1.75853164, -1.44137093, -1.12421022, -0.80704951, -0.4898888 ,
#         -0.17272809,  0.14443262,  0.46159333,  0.77875404,  1.09591475,
#          1.41307545,  1.73023616,  2.04739687,  2.36455758,  2.68171829,
#          2.998879  ,  3.31603971,  3.63320042,  3.95036113,  4.26752184,
#          4.58468255,  4.90184326,  5.21900397,  5.53616467,  5.85332538,
#          6.17048609,  6.4876468 ,  6.80480751,  7.12196822,  7.43912893,
#          7.75628964,  8.07345035,  8.39061106,  8.70777177,  9.02493248,
#          9.34209318]),
#  <BarContainer object of 40 artists>)

# %%
rng = np.random.default_rng(1)
x1 = rng.normal(0, 0.8, 1000)
x2 = rng.normal(-2, 1, 1000)
x3 = rng.normal(3, 2, 1000)

print(np.histogram(x1, bins=1))
print(np.histogram(x1, bins=2))
print(np.histogram(x1, bins=40))
# Out:
# (array([1000], dtype=int64), array([-2.83904398,  3.00130797]))
# (array([564, 436], dtype=int64), array([-2.83904398,  0.081132  ,  3.00130797]))
# (array([ 1,  0,  1,  0,  4,  3,  4, 11,  5, 14, 18, 33, 35, 48, 44, 58, 63,
#        73, 64, 85, 81, 52, 60, 55, 68, 26, 25, 17, 12, 19,  6,  8,  1,  2,
#         1,  1,  1,  0,  0,  1], dtype=int64), array([-2.83904398, -2.69303518, -2.54702638, -2.40101758, -2.25500878,
#        -2.10899998, -1.96299118, -1.81698239, -1.67097359, -1.52496479,
#        -1.37895599, -1.23294719, -1.08693839, -0.94092959, -0.79492079,
#        -0.648912  , -0.5029032 , -0.3568944 , -0.2108856 , -0.0648768 ,
#         0.081132  ,  0.2271408 ,  0.3731496 ,  0.51915839,  0.66516719,
#         0.81117599,  0.95718479,  1.10319359,  1.24920239,  1.39521119,
#         1.54121999,  1.68722878,  1.83323758,  1.97924638,  2.12525518,
#         2.27126398,  2.41727278,  2.56328158,  2.70929038,  2.85529918,
#         3.00130797]))

# %% [markdown]
# Двумерные гистограммы

# %%
mean = [0, 0]
cov = [[1, 1], [1, 2]]

x, y = rng.multivariate_normal(mean, cov, 10000).T

""" plt.hist2d(x, y, bins=30) """
plt.hexbin(x, y, gridsize=30)
cb = plt.colorbar()
cb.set_label('Point in interval')

# %% [markdown]
# Легенда

# %%
x = np.linspace(0, 10, 1000)

fig, ax = plt.subplots()

y = np.sin(x[:, np.newaxis] + np.pi * np.arange(0, 2, 0.5))

lines = plt.plot(x, y) # plt.Line2d
""" plt.legend(lines, [1, 'второй', 'third', '4-ый'], loc='upper left') """

plt.legend(lines[:2], ['1', '2'])

""" ax.plot(x, np.sin(x), label='Синус')
ax.plot(x, np.cos(x), label='Косинус')
ax.plot(x, np.cos(x) + 2, label='Косинус')
ax.axis('equal')
ax.legend(frameon=False, fancybox=True, shadow=True) """
# Out:
# " ax.plot(x, np.sin(x), label='Синус')\nax.plot(x, np.cos(x), label='Косинус')\nax.plot(x, np.cos(x) + 2, label='Косинус')\nax.axis('equal')\nax.legend(frameon=False, fancybox=True, shadow=True) "

# %%
cities = pd.read_csv('./data/california_cities.csv')

lat, lon, pop, area = cities['latd'], cities['longd'], cities['population_total'], cities['area_total_km2']

plt.scatter(lon, lat, c=np.log10(pop), s=area)
plt.xlabel('Широта')
plt.ylabel('долгота')
plt.colorbar()
plt.clim(3, 7)
plt.scatter([], [], c='k', alpha=0.5, s=100, label='100 $km^2$')
plt.scatter([], [], c='k', alpha=0.5, s=300, label='300 $km^2$')
plt.scatter([], [], c='k', alpha=0.5, s=500, label='500 $km^2$')
plt.legend(labelspacing=3, frameon=False)

# %%
fig, ax = plt.subplots()

lines = []
styles = ['-', '--', '-.', ':']
x = np.linspace(0, 10, 1000)
for i in range(4):
    lines += ax.plot(x, np.sin(x - i + np.pi / 2), styles[i])

ax.axis('equal')
ax.legend(lines[:2], ['line1', 'line2'], loc='upper right')

leg = mpl.legend.Legend(ax, lines[1:], ['line2', 'line3', 'line4'], loc='lower left')
ax.add_artist(leg)

# %% [markdown]
# Шкалы

# %%
x = np.linspace(0, 10, 1000)
y = np.sin(x) * np.cos(x[:, np.newaxis])

# %% [markdown]
# Карты цветов

# %% [markdown]
# Последовательные

# %%
""" plt.imshow(y, cmap='binary') """
plt.imshow(y, cmap='viridis')
plt.colorbar()

# %% [markdown]
# Дивергентные (два цвета)

# %%
""" plt.imshow(y, cmap='RdBu') """
plt.imshow(y, cmap='PuOr')
plt.colorbar()

# %% [markdown]
# Качественные (смешиваются без четкого порядка)

# %%
""" plt.imshow(y, cmap='rainbow') """
plt.imshow(y, cmap='jet')
plt.colorbar()

# %%
plt.figure()
plt.subplot(2, 1, 1)
plt.imshow(y, cmap='viridis')
plt.colorbar()

plt.subplot(2, 1, 2)
plt.imshow(y, cmap=plt.cm.get_cmap('viridis', 6))
plt.colorbar()
plt.clim(-0.25, 0.25)
# Out:
# C:\Users\n1luh\AppData\Local\Temp\ipykernel_13596\2749865308.py:7: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   plt.imshow(y, cmap=plt.cm.get_cmap('viridis', 6))

# %%
""" ax1 = plt.axes()
# [нижний угол, левый угол, ширина, высота]
ax2 = plt.axes([0.4, 0.3, 0.2, 0.1]) """

fig = plt.figure()

ax1 = fig.add_axes([0.1, 0.5, 0.8, 0.4])
ax2 = fig.add_axes([0.1, 0.1, 0.8, 0.4])

ax1.plot(np.sin(x))
ax2.plot(np.cos(x))

# %% [markdown]
# Простые сетки

# %%
fig = plt.figure()
fig.subplots_adjust(hspace=0.4, wspace=0.4)
for i in range(1, 7):
    ax = fig.add_subplot(2, 3, i)
    ax.plot(np.sin(x + np.pi / 4 * i))
